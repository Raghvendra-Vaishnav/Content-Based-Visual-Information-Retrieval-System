# %%
from transformers import Blip2Processor, Blip2ForConditionalGeneration
from PIL import Image
import torch

# %%
# Load model and processor
processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")

# %%
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", device_map="auto", dtype=torch.float16)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# c:\Users\harsh\miniconda3\Lib\site-packages\accelerate\utils\modeling.py:1598: UserWarning: The following device_map keys do not match any submodules in the model: ['query_tokens']
#   warnings.warn(
# Some parameters are on the meta device because they were offloaded to the cpu.

# %%
# Load image
image = Image.open("image.png").convert("RGB")

# %%
# Prompted captioning
inputs = processor(images=image, return_tensors="pt").to("cuda", torch.float16)

# %%
# Generate caption
generated_ids = model.generate(**inputs, max_new_tokens=100)
caption = processor.decode(generated_ids[0], skip_special_tokens=True)
print("BLIP-2 Caption:", caption)
# Out:
# BLIP-2 Caption: a boy and his dog playing soccer on a field
